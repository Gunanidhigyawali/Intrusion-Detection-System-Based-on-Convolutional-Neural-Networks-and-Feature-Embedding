# %%
# !ls
# Out:
#  Untitled.ipynb  'archive (1).zip'   main.py

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Wed_Aug_20_01:58:59_PM_PDT_2025
# Cuda compilation tools, release 13.0, V13.0.88
# Build cuda_13.0.r13.0/compiler.36424714_0

# %%
# !nvidia-smi
# Out:
# Mon May  4 10:26:10 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.20             Driver Version: 580.126.20     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 6000 Blac...    Off |   00000000:2F:00.0 Off |                    0 |
# | N/A   23C    P8             28W /  600W |       0MiB /  97887MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
! git clone https://github.com/rabisubedichettri/Intrusion_detection.git
# Out:
# Cloning into 'Intrusion_detection'...

# %%
# !pwd
# Out:
# /teamspace/studios/this_studio/Intrusion_detection

# %%
# %cd Intrusion_detection
# Out:
# /teamspace/studios/this_studio/Intrusion_detection
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# config.py    inference.py  model.py	     training
# evaluations  main.py	   preprocessing.py

# %%
import zipfile

zip_path = "/teamspace/studios/this_studio/archive (1).zip"
extract_path = "/teamspace/studios/this_studio/datasets"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extracted to:", extract_path)
# Out:
# Extracted to: /teamspace/studios/this_studio/datasets

# %%
# %ls
# Out:
# config.py     inference.py  model.py          training/
# evaluations/  main.py       preprocessing.py

# %%
! python main.py train --epochs 50
# Out:
# Device      : cuda
# Data        : /teamspace/studios/this_studio/datasets/casia-webface/
# Epochs      : 50
# LR          : 0.1
# Batch size  : 512
# Output dir  : training
# Device : cuda
#
# 🔄 Splitting dataset...
#
#   Train : 367,967 images  (all 10572 identities)
#   Val   : 122,656 images  (full 25% — no cap)
#   ArcFace classes : 10572
#
# Fresh run — epoch 1 uses ImageNet pretrained backbone
#   Result file → training/training_result.json
#
# Epoch 1/50  lr=1.00e-03
#   Train  loss=20.2577  acc=0.43%
#   Val    loss=8.8703  acc=1.80%
#   Gap    -1.37%
#
#   ✅ New best  (val_acc=1.80%)
#
#   💾 Checkpoint → training/checkpoint_epoch_1.pth
#
# Epoch 2/50  lr=3.40e-02
#   ↩  Best weights loaded  (val_acc=1.80%)
#   Train  loss=16.3262  acc=25.15%
#   Val    loss=4.9147  acc=38.29%
#   Gap    -13.13%
#
#   ✅ New best  (val_acc=38.29%)
#
#   💾 Checkpoint → training/checkpoint_epoch_2.pth
#
# Epoch 3/50  lr=6.70e-02
#   ↩  Best weights loaded  (val_acc=38.29%)
# ...
